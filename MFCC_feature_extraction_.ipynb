# %%
import IPython.display as ipd
filepath = "/content/sample_data/ggg.wav"
ipd.Audio(filepath)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
data, sample_rate = librosa.load(filepath)
plt.figure(figsize=(12, 5))
librosa.display.waveshow(data, sr=sample_rate)
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")

# %%
x=librosa.stft(data)
xbd=librosa.amplitude_to_db(abs(x))
plt.figure(figsize=(14,5))
librosa.display.specshow(xbd, sr=sample_rate , x_axis='time', y_axis='hz')
plt.colorbar()

# %%
mfccs = librosa.feature.mfcc(y=data, sr=sample_rate)
print(mfccs.shape)
print(mfccs)
# Out:
# (20, 65)
# [[-592.6572    -592.6572    -522.98096   ... -592.6572    -592.6572
#   -592.6572   ]
#  [   0.           0.          86.97534   ...    0.           0.
#      0.       ]
#  [   0.           0.          58.24112   ...    0.           0.
#      0.       ]
#  ...
#  [   0.           0.          -1.3349035 ...    0.           0.
#      0.       ]
#  [   0.           0.          -2.8826275 ...    0.           0.
#      0.       ]
#  [   0.           0.          -3.873644  ...    0.           0.
#      0.       ]]
